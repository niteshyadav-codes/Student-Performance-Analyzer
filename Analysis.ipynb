# %%
import pandas as pd

# %%
df=pd.read_csv("students_100.csv")
# df

# %%
print("Using Head Method")
print(df.head())
# Out:
# Using Head Method
#        Name  Age Course  Marks      City
# 0  Student1   19  BTech     63     Delhi
# 1  Student2   20   BCom     66    Kanpur
# 2  Student3   21    BCA     69  Varanasi
# 3  Student4   18  BTech     72      Agra
# 4  Student5   19   BCom     75     Noida

# %%
print("Using Tail Method")
print(df.tail())
# Out:
# Using Tail Method
#           Name  Age Course  Marks      City
# 95   Student96   18    BCA     61   Lucknow
# 96   Student97   19  BTech     64     Delhi
# 97   Student98   20   BCom     67    Kanpur
# 98   Student99   21    BCA     70  Varanasi
# 99  Student100   18  BTech     73      Agra

# %%
print("Using Info Method")
print(df.info())
# Out:
# Using Info Method
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    100 non-null    str
#  1   Age     100 non-null    int64
#  2   Course  100 non-null    str
#  3   Marks   100 non-null    int64
#  4   City    100 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 4.0 KB
# None

# %%
print("Usinf Describe Method")
print(df.describe())
# Out:
# Usinf Describe Method
#               Age       Marks
# count  100.000000  100.000000
# mean    19.500000   79.480000
# std      1.123666   11.908303
# min     18.000000   60.000000
# 25%     18.750000   69.000000
# 50%     19.500000   79.000000
# 75%     20.250000   90.000000
# max     21.000000  100.000000

# %%
print("Average Marks")
Avg_marks=df["Marks"].mean()
print(Avg_marks)
# Out:
# Average Marks
# 79.48

# %%
print("Highest Marks")
print(df["Marks"].max())
# Out:
# Highest Marks
# 100

# %%
print("Lowest Marks")
print(df["Marks"].min())
# Out:
# Lowest Marks
# 60

# %%
print("Topper")
df[df["Marks"] == df["Marks"].max()]
# Out:
# Topper
#          Name  Age Course  Marks      City
# 26  Student27   21    BCA    100  Varanasi
# 67  Student68   18   BCom    100      Agra

# %%
print("Total Students")
print(len(df))
# Out:
# Total Students
# 100

# %%
print("Student above 80 marks")
print(df[df["Marks"]>80])
# Out:
# Student above 80 marks
#          Name  Age Course  Marks       City
# 6    Student7   21  BTech     81  Gorakhpur
# 7    Student8   18   BCom     84    Lucknow
# 8    Student9   19    BCA     87      Delhi
# 9   Student10   20  BTech     90     Kanpur
# 10  Student11   21   BCom     93   Varanasi
# 11  Student12   18    BCA     96       Agra
# 12  Student13   19  BTech     99      Noida
# 20  Student21   19    BCA     82      Noida
# 21  Student22   20  BTech     85  Prayagraj
# 22  Student23   21   BCom     88  Gorakhpur
# 23  Student24   18    BCA     91    Lucknow
# 24  Student25   19  BTech     94      Delhi
# 25  Student26   20   BCom     97     Kanpur
# 26  Student27   21    BCA    100   Varanasi
# 34  Student35   21   BCom     83   Varanasi
# 35  Student36   18    BCA     86       Agra
# 36  Student37   19  BTech     89      Noida
# 37  Student38   20   BCom     92  Prayagraj
# 38  Student39   21    BCA     95  Gorakhpur
# 39  Student40   18  BTech     98    Lucknow
# ...

# %%
print("Columns")
print(df.columns)
# Out:
# Columns
# Index(['Name', 'Age', 'Course', 'Marks', 'City'], dtype='str')

# %%
print("Project Summary ")
print("Total Student: ", len(df))
print("Average Marks : ",df["Marks"].mean())
print("Highest Marks: ", df["Marks"].max())
print("Lowest Marks: " , df["Marks"].min())
# Out:
# Project Summary
# Total Student:  100
# Average Marks :  79.48
# Highest Marks:  100
# Lowest Marks:  60
